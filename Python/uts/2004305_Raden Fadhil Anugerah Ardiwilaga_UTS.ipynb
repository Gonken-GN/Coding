# %%
import pandas as pd
df =pd.read_csv("covid19_sg.csv")
df
# Out:
#            Date  Daily Confirmed  False Positives Found  Cumulative Confirmed  \
# 0    2020-01-23                1                    NaN                     1
# 1    2020-01-24                2                    NaN                     3
# 2    2020-01-25                1                    NaN                     4
# 3    2020-01-26                0                    NaN                     4
# 4    2020-01-27                1                    NaN                     5
# ..          ...              ...                    ...                   ...
# 636  2021-10-20             3862                    0.0                158587
# 637  2021-10-21             3439                    0.0                162026
# 638  2021-10-22             3637                    0.0                165663
# 639  2021-10-23             3598                    0.0                169261
# 640  2021-10-24             3383                    0.0                172644
#
# ...

# %% [markdown]
# ## Nama: Raden Fadhil Anugerah Ardiwilaga
# ## NIM: 2004305

# %%
maxValue = df["Daily Deaths"].max()
print(maxValue)
# Out:
# 18

# %%
df.loc[636]
# Out:
# Date                                                                      2021-10-20
# Daily Confirmed                                                                 3862
# False Positives Found                                                            0.0
# Cumulative Confirmed                                                          158587
# Daily Discharged                                                                2715
# Passed but not due to COVID                                                        0
# Cumulative Discharged                                                         130308
# Discharged to Isolation                                                        26319
# Still Hospitalised                                                              1688
# Daily Deaths                                                                      18
# Cumulative Deaths                                                                264
# ...

# %%
df['Date'].is_unique
# Out:
# True

# %%
df_groupby_phase = df.groupby("Phase")
df_groupby_phase["Phase"].count()
# Out:
# Phase
# Circuit Breaker                56
# Phase 1                        17
# Phase 2                       200
# Phase 2 (Heightened Alert)     48
# Phase 3                       131
# Phase 3 (Heightened Alert)     38
# Preparatory Stage              47
# Stabilisation Phase            29
# Name: Phase, dtype: int64

# %%
corr = df[['Passed but not due to COVID','Daily Deaths']]

corr1 = corr.corr()
corr1
# Out:
#                              Passed but not due to COVID  Daily Deaths
# Passed but not due to COVID                      1.00000      -0.02447
# Daily Deaths                                    -0.02447       1.00000
